# %% [markdown]
# #Extracción, exploración y analisis datos en netflix

# %% [markdown]
# Este es un proyecto a modo de autoestudio que tiene como enfasis el proceso ETL o Extract, Transform y Load; para este caso, un dataset que contiene datos de netflix con la cual se hará la manipulación de los mismos. La finalidad es poner en practica mis capacidades y adquierir nuevas destrezas.
#
# Realizado por: Luis Felipe Sanchez Sanchez
#
# [Dataset](https://www.kaggle.com/datasets/shivamb/netflix-shows?resource=download)

# %% [markdown]
# ##Librerias y conexiones

# %% [markdown]
# Importamos librerias

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.9/33.9 MB 54.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector

# %%
#Conectamos google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importamos el dataset
df = pd.read_csv('/content/drive/MyDrive/Ejecicios de practica/Extracción-Analísis-Netflix/netflix_titles.csv')

# %%
#Creamos la conexión a base de datos de mysql
conexion = mysql.connector.connect(
    user='root',
    password='root',
    host='localhost',
    database='',
    port='3306')
print(conexion)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/mysql/connector/network.py in open_connection(self)
#     794             self.sock.settimeout(self._connection_timeout)
# --> 795             self.sock.connect(sockaddr)
#     796         except (socket.timeout, TimeoutError) as err:
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-8-65bfa13ca2ab> in <cell line: 0>()
#       2
#       3 # Connect to MySQL without specifying a database
# ----> 4 conexion = mysql.connector.connect(
#       5     user='root',
#       6     password='root',
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/pooling.py in connect(*args, **kwargs)
# ...
