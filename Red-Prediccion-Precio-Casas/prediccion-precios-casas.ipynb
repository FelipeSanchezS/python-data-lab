# %% [markdown]
# #Modelo de predicción - precio de casas
#
# Este es un modelo de predicción sencillo y basico enfocado en la predicción del costo de una casa segun varias caractaristicas que se encuentran dentro del conjunto de datos; todo esto se hizo siguiendo un video a modo de autoestudio
#
# Para esto se hizo uso del algoritmo de regresión, arbol de desiciones.
#
# Elaborado por: *Luis Felipe Sanchez Sanchez*

# %% [markdown]
# ##Importación de librerias

# %%
#Importamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ##Cargue de datos

# %%
#conectamos con google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importamos el dataset
df = pd.read_csv('/content/drive/MyDrive/Ejecicios de practica/Red-Prediccion-Precio-Casas/melb_data.csv')

# %%
df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
#cambiamos el nombre de Innamed: 0 por ID
df.rename(columns={'Unnamed: 0':'ID'}, inplace=True)

# %% [markdown]
# ##Limpieza de datos

# %%
#contamos la cantidad de valores nulos por columna
df.isnull().sum()
# Out:
# ID                   0
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          3469
# Bathroom          3471
# Car               3576
# Landsize          4793
# BuildingArea     10634
# YearBuilt         9438
# CouncilArea       6163
# Lattitude         3332
# Longtitude        3332
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
#eliminamos la fila con valores faltantes
df.dropna(inplace=True)

# %%
#contamos si hay valores faltantes
df.isnull().sum()
# Out:
# ID               0
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %% [markdown]
# ##Modelo predictivo

# %%
#Creamos la variable x y y para el modelo
y = df['Price'] #Variable dependiente o a predecir
x = df[['Rooms','Bathroom','Landsize','Lattitude','Longtitude']] #Variables que se toman como base para predecir

# %%
#Para este caso usamos el algoritmo de arbol de desición, regresión
modelo_predic = DecisionTreeRegressor()
#entrenamos el modelo
modelo_predic = modelo_predic.fit(x,y)

# %%
##prediccion para las priemras casas
modelo_predic.predict(x.head())
# Out:
# array([1035000., 1465000., 1600000., 1876000., 1636000.])

# %%
# @title
#complementamos con mas datos la predicción
print("Las predicciones son")
print(modelo_predic.predict(x.head()))
print('Los valores reales son')
print(y.head().tolist())
# Out:
# Las predicciones son
# [1035000. 1465000. 1600000. 1876000. 1636000.]
# Los valores reales son
# [1035000.0, 1465000.0, 1600000.0, 1876000.0, 1636000.0]

# %% [markdown]
# ##Metricas de error

# %%
# Si el modelo está en la primera posición
mean_absolute_error(y, modelo_predic.predict(x))
# Out:
# 1115.7467183128902

# %%
#validacion
train_x, val_x, train_y, val_y = train_test_split(x,y,random_state=0)
df = DecisionTreeRegressor()
df.fit(train_x,train_y)
# Out:
# DecisionTreeRegressor()

# %%
val_predic = df.predict(val_x)
print(mean_absolute_error(val_y,val_predic))
# Out:
# 274801.0628362385

# %%
def get_mae(max_leaf_nodes, train_x, val_x, train_y, val_y):
  model = DecisionTreeRegressor(max_leaf_nodes=max_leaf)
  model.fit(train_x,train_y)
  preds_val = model.predict(val_x)
  mae = mean_absolute_error(val_y,preds_val)
  return(mae)

# %%
for max_leaf_nodes in [5,50,500,5000]:
  my_mae = get_mae(max_leaf_nodes, train_x, val_x, train_y, val_y)
  print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
